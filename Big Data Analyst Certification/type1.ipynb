# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60399 entries, 0 to 60398
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           60399 non-null  object
#  1   channelTitle    60399 non-null  object
#  2   categoryId      60399 non-null  int64
#  3   view_count      60399 non-null  int64
#  4   likes           60399 non-null  int64
#  5   dislikes        60399 non-null  int64
#  6   comment_count   60399 non-null  int64
#  7   channelId       60399 non-null  object
#  8   trending_date2  60399 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 4.6+ MB

# %%
# 조회수(view_count) 상위 5개 동영상 조회
df.sort_values('view_count', ascending=False).head(5)
# Out:
#                                   title channelTitle  categoryId  view_count  \
# 30583  BTS (방탄소년단) 'Butter' Official MV  HYBE LABELS          10   296314174
# 30383  BTS (방탄소년단) 'Butter' Official MV  HYBE LABELS          10   292502967
# 30174  BTS (방탄소년단) 'Butter' Official MV  HYBE LABELS          10   289350312
# 29964  BTS (방탄소년단) 'Butter' Official MV  HYBE LABELS          10   285698612
# 29729  BTS (방탄소년단) 'Butter' Official MV  HYBE LABELS          10   282265069
#
#           likes  dislikes  comment_count                 channelId  \
# 30583  16464253    181350        6939302  UC3IZKseVpdzPSBaWxBxundA
# 30383  16413537    178381        6913277  UC3IZKseVpdzPSBaWxBxundA
# 30174  16369715    175204        6889393  UC3IZKseVpdzPSBaWxBxundA
# 29964  16319755    172331        6864694  UC3IZKseVpdzPSBaWxBxundA
# 29729  16272565    168794        6845770  UC3IZKseVpdzPSBaWxBxundA
#
#       trending_date2
# 30583     2021-06-04
# 30383     2021-06-03
# 30174     2021-06-03
# ...

# %%
# 평균 좋아요(likes) 반올림 계산
round(df['likes'].mean())
# Out:
# 78471
